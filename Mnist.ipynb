# %% [markdown]
# <a href="https://colab.research.google.com/github/mmadeshwaran/Machine-Learning/blob/master/Mnist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

#install Tensorflow
# !pip install tensorflow==2.0.0-rc0 

import tensorflow as tf

# %%
mnist=tf.keras.datasets.mnist

(x_train, y_train),(x_test,y_test) = mnist.load_data()

#Normalize the data
x_train,x_test = x_train/255.0, x_test/255.0

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Flatten(input_shape=(28,28)),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(10,activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.fit(x_train,y_train,epochs=5)
model.evaluate(x_test,y_test)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 7s 116us/sample - loss: 0.2993 - accuracy: 0.9127
# Epoch 2/5
# 60000/60000 [==============================] - 6s 102us/sample - loss: 0.1443 - accuracy: 0.9574
# Epoch 3/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.1077 - accuracy: 0.9676
# Epoch 4/5
# 60000/60000 [==============================] - 5s 88us/sample - loss: 0.0889 - accuracy: 0.9719
# Epoch 5/5
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.0756 - accuracy: 0.9768
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# [0.07782736482797191, 0.9781]
